# %% [markdown]
# <a href="https://colab.research.google.com/github/quocthang0507/VietnameseNaturalLanguageProcessing/blob/main/Simalign_and_Pyvi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PyVi Github repo: https://github.com/trungtv/pyvi
#
# Simalign Github repo: https://github.com/cisnlp/simalign
#
# Citation
#
# ```
# @inproceedings{jalili-sabet-etal-2020-simalign,
#     title = "{S}im{A}lign: High Quality Word Alignments without Parallel Training Data using Static and Contextualized Embeddings",
#     author = {Jalili Sabet, Masoud  and
#       Dufter, Philipp  and
#       Yvon, Fran{\c{c}}ois  and
#       Sch{\"u}tze, Hinrich},
#     booktitle = "Proceedings of the 2020 Conference on Empirical Methods in Natural Language Processing: Findings",
#     month = nov,
#     year = "2020",
#     address = "Online",
#     publisher = "Association for Computational Linguistics",
#     url = "https://www.aclweb.org/anthology/2020.findings-emnlp.147",
#     pages = "1627--1643",
# }
# ```

# %%
# !pip install pyvi
# !pip install --upgrade git+https://github.com/cisnlp/simalign.git#egg=simalign
# Out:
# ...
#      |████████████████████████████████| 8.5 MB 4.5 MB/s
# ...
#      |████████████████████████████████| 743 kB 46.4 MB/s
# ...
#   Cloning https://github.com/cisnlp/simalign.git to /tmp/pip-install-k_96f_g1/simalign_6cab8d32568e4916bfa437dd10092274
#   Running command git clone -q https://github.com/cisnlp/simalign.git /tmp/pip-install-k_96f_g1/simalign_6cab8d32568e4916bfa437dd10092274
# ...
#      |████████████████████████████████| 2.6 MB 5.4 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 37.9 MB/s
# ...
#      |████████████████████████████████| 636 kB 44.7 MB/s
# ...
#      |████████████████████████████████| 895 kB 22.6 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 49.4 MB/s
# ...
#   Created wheel for simalign: filename=simalign-0.2-py3-none-any.whl size=5575 sha256=6a80c97e1e51959f5e54c6fc097e07a3c493e8c701493738f06316d3eed47f56
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6k41smzq/wheels/7c/fd/e8/feb79b708710c76e78b833a417552cadc858dd3d2ee5897585
# Successfully built simalign
# ...

# %%
from pyvi import ViTokenizer
from simalign import SentenceAligner

# %%
myaligner = SentenceAligner(model="bert", token_type="bpe", matching_methods="mai")
# Out:
# Downloading:   0%|          | 0.00/625 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-multilingual-cased were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
src = 'Bà ta xuất hiện trong nhiều tấm hình lớn ở hiện trường.'
tgt = 'She appears in many big photos at the scene.'

# %%
sent_src = [i.replace('_', ' ') for i in ViTokenizer.tokenize(src).split()]
sent_tgt = [i.replace('_', ' ') for i in ViTokenizer.tokenize(tgt).split()]

# %%
alignments = myaligner.get_word_aligns(sent_src, sent_tgt)

# %%
for matching_method in alignments:
    print(matching_method , ':')
    for result in alignments[matching_method]:
        print('\t', sent_src[result[0]], '===', sent_tgt[result[1]])
# Out:
# mwmf :
# 	 Bà === She
# 	 xuất hiện === appears
# 	 trong === in
# 	 nhiều === many
# 	 hình === photos
# 	 lớn === big
# 	 ở === at
# 	 hiện trường === the
# 	 hiện trường === scene
# 	 . === .
# inter :
# 	 Bà === She
# 	 xuất hiện === appears
# 	 trong === in
# 	 nhiều === many
# 	 hình === photos
# 	 lớn === big
# 	 ở === at
# 	 hiện trường === the
# 	 hiện trường === scene
# 	 . === .
# itermax :
# 	 Bà === She
# 	 xuất hiện === appears
# 	 trong === in
# 	 nhiều === many
# 	 hình === photos
# 	 lớn === big
# 	 ở === at
# 	 hiện trường === the
# 	 hiện trường === scene
# 	 . === .
